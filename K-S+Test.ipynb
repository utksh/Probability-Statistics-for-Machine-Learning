# %% [markdown]
# # K-S Test

# %% [markdown]
# The Kolmogorov–Smirnov test is used to test whether two underlying one-dimensional probability distributions differ.

# %%
from IPython.display import Image
Image(filename='300px-KS2_Example.png')

# %% [markdown]
# The hypotheses for the test are:
#
# Null hypothesis (H0): the data comes from the specified distribution.<br>
# Alternate Hypothesis (H1): at least one value does not match the specified distribution.<br>
#
# That is,
# ### H0: P = P0, H1: P ≠ P0.<br>
# Where P is the distribution of your sample (i.e. the EDF) and P0 is a specified distribution

# %%
#The test statistic for the following hypothesis is
from IPython.display import Image
Image(filename='Capture.png')

# %% [markdown]
# where F(1,n) and F(2,m) are the empirical distribution functions of the first and the second sample respectively, and Sup  is the supremum function.

# %% [markdown]
# The null hypothesis is rejected at level alpha if

# %%
from IPython.display import Image
Image(filename = 'Capture1.png')

# %% [markdown]
# Where **n** and **m** are the sizes of first and second sample respectively.<br> **c(alpha)** is calculated using the undergiven formulae.

# %%
from IPython.display import Image
Image(filename = 'capture3.png')

# %%
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %%
#Normal distribution random variables
x = stats.norm.rvs(size = 1000)
sns.set_style('whitegrid')
sns.kdeplot(np.array(x), bw =0.5)
plt.show()

# %%
#Peforming K-S test on the above random variable and comparing it to normal distribution
stats.kstest(x, 'norm')
# Out:
# KstestResult(statistic=0.042689169021848272, pvalue=0.050756159164127013)

# %% [markdown]
# The result gives a statistic value(D(n,m)) of 0.0426 and the pvalue(c(alpha)) of 0.0507. <br>
# That means D(n,m) < C(alpha).
#
# Thus we accept Null Hypothesis i.e the data comes from the specified distribution(Normal Distribution)

# %%
#Unifrom distribution random variable
y = stats.uniform.rvs(size=1000)
sns.kdeplot(np.array(y), bw = 0.1)
plt.show()

# %%
stats.kstest(y,'norm')
# Out:
# KstestResult(statistic=0.50030666067963425, pvalue=0.0)

# %% [markdown]
# The statistic > pvalue ,
# Thus rejecting Null hypothesis(H0) and accepting (H1), which is at least one value does not match the specified distribution.
